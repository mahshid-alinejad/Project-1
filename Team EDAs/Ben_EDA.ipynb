# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pandas as pd
from prophet import Prophet
import datetime as dt
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

import matplotlib.dates as mdates
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./Resource/US_youtube_trending_data.csv")
display(df.head())
df.tail()
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId   channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends          20
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye          24
# 3  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg            XXL          10
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate          26
#
#           trending_date                                               tags  \
# 0  2020-08-12T00:00:00Z  brawadis|prank|basketball|skits|ghost|funny vi...
# 1  2020-08-12T00:00:00Z  Apex Legends|Apex Legends characters|new Apex ...
# 2  2020-08-12T00:00:00Z  jacksepticeye|funny|funny meme|memes|jacksepti...
# 3  2020-08-12T00:00:00Z  xxl freshman|xxl freshmen|2020 xxl freshman|20...
# 4  2020-08-12T00:00:00Z  The LaBrant Family|DIY|Interior Design|Makeove...
#
#    view_count   likes  dislikes  comment_count  \
# 0     1514614  156908      5855          35313
# 1     2381688  146739      2794          16549
# 2     2038853  353787      2628          40221
# 3      496771   23251      1856           7647
# 4     1123889   45802       964           2196
#
#                                    thumbnail_link  comments_disabled  \
# 0  https://i.ytimg.com/vi/3C66w5Z0ixs/default.jpg              False
# 1  https://i.ytimg.com/vi/M9Pmf9AB4Mo/default.jpg              False
# 2  https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg              False
# 3  https://i.ytimg.com/vi/kXLn3HkpjaA/default.jpg              False
# 4  https://i.ytimg.com/vi/VIUo6yapDbc/default.jpg              False
#
#    ratings_disabled                                        description
# 0             False  SUBSCRIBE to BRAWADIS ▶ http://bit.ly/Subscrib...
# 1             False  While running her own modding shop, Ramya Pare...
# 2             False  I left youtube for a month and this is what ha...
# 3             False  Subscribe to XXL → http://bit.ly/subscribe-xxl...
# 4             False  Transforming The LaBrant Family's empty white ...
#            video_id                                              title  \
# 267982  ahx0iw78lUE                              Showing Jack my memes
# 267983  -Pcout3o4Fg  LeBron James Opens Up About The Miami Heat Lea...
# 267984  -MdZRXipEHg  Reunited With Our Daughter After 3 Months! *EM...
# 267985  njnpzWbhpK8  Poison (Official Remix) | Hazbin Hotel | Prime...
# 267986  u5P0n2t9RNA        Triple H Goes Sneaker Shopping With Complex
#
#                  publishedAt                 channelId  \
# 267982  2024-03-31T17:32:47Z  UC-lHJZR3Gqxm24_Vd_AJ5Yw
# 267983  2024-04-02T19:30:00Z  UC6L_LBqoKZXFa4WxHox5iCw
# 267984  2024-04-03T18:14:27Z  UCSxspw1FZ3K4bhdHhhibhqw
# 267985  2024-04-01T05:23:29Z  UCzfyYtgvkx5mLy8nlLlayYg
# 267986  2024-04-01T14:00:39Z  UCE_--R1P5-kfBzHTca0dsnw
#
#                                            channelTitle  categoryId  \
# 267982                                        PewDiePie          24
# 267983  Mind the Game Pod w/ LeBron James and JJ Redick          22
# 267984                                      Dad V Girls          24
# 267985                                        Vivziepop           1
# 267986                                          Complex          24
#
#                trending_date  \
# 267982  2024-04-11T00:00:00Z
# 267983  2024-04-11T00:00:00Z
# 267984  2024-04-11T00:00:00Z
# 267985  2024-04-11T00:00:00Z
# 267986  2024-04-11T00:00:00Z
#
#                                                      tags  view_count   likes  \
# 267982  pewdiepie|pewds|pewdie|jack|pewdiepie jacksept...     2333425  161250
# 267983  lebron james|jj redick|lebron james jj redick|...      691381   19514
# 267984  Dad V Girls|Dad|Girls|Dad Vs Girls|Family|Fami...      584315   17181
# 267985                                Vivziepop|Zoophobia     1500159  145948
# 267986  Triple H|WWE|wwe raw|wrestlemania 40|roman rei...     1212337   41642
#
#         dislikes  comment_count  \
# 267982         0           4128
# 267983         0           2366
# 267984         0            667
# 267985         0          10538
# 267986         0           2912
#
#                                         thumbnail_link  comments_disabled  \
# 267982  https://i.ytimg.com/vi/ahx0iw78lUE/default.jpg              False
# 267983  https://i.ytimg.com/vi/-Pcout3o4Fg/default.jpg              False
# 267984  https://i.ytimg.com/vi/-MdZRXipEHg/default.jpg              False
# 267985  https://i.ytimg.com/vi/njnpzWbhpK8/default.jpg              False
# 267986  https://i.ytimg.com/vi/u5P0n2t9RNA/default.jpg              False
#
#         ratings_disabled                                        description
# 267982             False  🌏 Get exclusive NordVPN deal here ➵ https://No...
# 267983             False  In this preview clip for Episode 3, LeBron Jam...
# 267984             False  👉 Join the DVG Fam: https://bit.ly/2lf0X8J📸  D...
# 267985             False  Get a taste of poison…Performed by Roman, orig...
# 267986             False  WWE Legend Triple H goes Sneaker Shopping with...

# %%
df.columns
# Out:
# Index(['video_id', 'title', 'publishedAt', 'channelId', 'channelTitle',
#        'categoryId', 'trending_date', 'tags', 'view_count', 'likes',
#        'dislikes', 'comment_count', 'thumbnail_link', 'comments_disabled',
#        'ratings_disabled', 'description'],
#       dtype='object')

# %%
df['view_count'].sort_values(ascending= False)
# Out:
# 266187    1407643634
# 266388    1406329649
# 265987     628718636
# 152788     277791741
# 152568     273162966
#              ...
# 49597              0
# 126641             0
# 126404             0
# 200521             0
# 20184              0
# Name: view_count, Length: 267987, dtype: int64

# %%
#Views and Likes and title 
#Views/Dislikes
#Category ID and Views/Likes/Dislikes/Comment Count
#Publish Time and Views/Comment Count

# %%
df['likes'].sort_values(ascending= False)
# Out:
# 56374     16021534
# 3358      15735533
# 3137      15460822
# 2894      15246496
# 2653      14994034
#             ...
# 28118            0
# 217710           0
# 217735           0
# 107828           0
# 177394           0
# Name: likes, Length: 267987, dtype: int64

# %%
top_10_most_viewed = df.sort_values(by='view_count', ascending=False).head(10)
top_10_most_viewed
# Out:
#            video_id                             title           publishedAt  \
# 266187  cc2-4ci4G84      Discord Loot Boxes are here.  2024-04-01T17:46:17Z
# 266388  cc2-4ci4G84      Discord Loot Boxes are here.  2024-04-01T17:46:17Z
# 265987  cc2-4ci4G84      Discord Loot Boxes are here.  2024-04-01T17:46:17Z
# 152788  gQlMMD8auMs      BLACKPINK - ‘Pink Venom’ M/V  2022-08-19T04:00:13Z
# 152568  gQlMMD8auMs      BLACKPINK - ‘Pink Venom’ M/V  2022-08-19T04:00:13Z
# 152365  gQlMMD8auMs      BLACKPINK - ‘Pink Venom’ M/V  2022-08-19T04:00:13Z
# 152175  gQlMMD8auMs      BLACKPINK - ‘Pink Venom’ M/V  2022-08-19T04:00:13Z
# 56374   WMweEpGlu_U  BTS (방탄소년단) 'Butter' Official MV  2021-05-21T03:46:13Z
# 151968  gQlMMD8auMs      BLACKPINK - ‘Pink Venom’ M/V  2022-08-19T04:00:13Z
# 151773  gQlMMD8auMs      BLACKPINK - ‘Pink Venom’ M/V  2022-08-19T04:00:13Z
#
#                        channelId channelTitle  categoryId  \
# 266187  UCZ5XnGb-3t7jCkXdawN2tkA      Discord          24
# 266388  UCZ5XnGb-3t7jCkXdawN2tkA      Discord          24
# 265987  UCZ5XnGb-3t7jCkXdawN2tkA      Discord          24
# 152788  UCOmHUn--16B90oW2L6FRR3A    BLACKPINK          10
# 152568  UCOmHUn--16B90oW2L6FRR3A    BLACKPINK          10
# 152365  UCOmHUn--16B90oW2L6FRR3A    BLACKPINK          10
# 152175  UCOmHUn--16B90oW2L6FRR3A    BLACKPINK          10
# 56374   UC3IZKseVpdzPSBaWxBxundA  HYBE LABELS          10
# 151968  UCOmHUn--16B90oW2L6FRR3A    BLACKPINK          10
# 151773  UCOmHUn--16B90oW2L6FRR3A    BLACKPINK          10
#
#                trending_date  \
# 266187  2024-04-03T00:00:00Z
# 266388  2024-04-04T00:00:00Z
# 265987  2024-04-02T00:00:00Z
# 152788  2022-09-10T00:00:00Z
# 152568  2022-09-09T00:00:00Z
# 152365  2022-09-08T00:00:00Z
# 152175  2022-09-07T00:00:00Z
# 56374   2021-05-30T00:00:00Z
# 151968  2022-09-06T00:00:00Z
# 151773  2022-09-05T00:00:00Z
#
#                                                      tags  view_count  \
# 266187                                             [None]  1407643634
# 266388                                             [None]  1406329649
# 265987                                             [None]   628718636
# 152788  YG Entertainment|YG|와이지|K-pop|BLACKPINK|블랙핑크|블...   277791741
# 152568  YG Entertainment|YG|와이지|K-pop|BLACKPINK|블랙핑크|블...   273162966
# 152365  YG Entertainment|YG|와이지|K-pop|BLACKPINK|블랙핑크|블...   268758295
# 152175  YG Entertainment|YG|와이지|K-pop|BLACKPINK|블랙핑크|블...   264459017
# 56374                     BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   264407389
# 151968  YG Entertainment|YG|와이지|K-pop|BLACKPINK|블랙핑크|블...   260126694
# 151773  YG Entertainment|YG|와이지|K-pop|BLACKPINK|블랙핑크|블...   255524865
#
#            likes  dislikes  comment_count  \
# 266187    126926         0          13987
# 266388    165173         0          17446
# 265987     47460         0           4829
# 152788  12993894         0        3534337
# 152568  12937252         0        3516745
# 152365  12882841         0        3504692
# 152175  12829059         0        3491132
# 56374   16021534    150989        6738537
# 151968  12773474         0        3479717
# 151773  12715882         0        3466961
#
#                                         thumbnail_link  comments_disabled  \
# 266187  https://i.ytimg.com/vi/cc2-4ci4G84/default.jpg              False
# 266388  https://i.ytimg.com/vi/cc2-4ci4G84/default.jpg              False
# 265987  https://i.ytimg.com/vi/cc2-4ci4G84/default.jpg              False
# 152788  https://i.ytimg.com/vi/gQlMMD8auMs/default.jpg              False
# 152568  https://i.ytimg.com/vi/gQlMMD8auMs/default.jpg              False
# 152365  https://i.ytimg.com/vi/gQlMMD8auMs/default.jpg              False
# 152175  https://i.ytimg.com/vi/gQlMMD8auMs/default.jpg              False
# 56374   https://i.ytimg.com/vi/WMweEpGlu_U/default.jpg              False
# 151968  https://i.ytimg.com/vi/gQlMMD8auMs/default.jpg              False
# 151773  https://i.ytimg.com/vi/gQlMMD8auMs/default.jpg              False
#
#         ratings_disabled                                        description
# 266187             False  Why would we ever bring Loot Boxes into a chat...
# 266388             False  Why would we ever bring Loot Boxes into a chat...
# 265987             False  Why would we ever bring Loot Boxes into a chat...
# 152788             False  BLACKPINK - ‘Pink Venom’ M/VKick in the door W...
# 152568             False  BLACKPINK - ‘Pink Venom’ M/VKick in the door W...
# 152365             False  BLACKPINK - ‘Pink Venom’ M/VKick in the door W...
# 152175             False  BLACKPINK - ‘Pink Venom’ M/VKick in the door W...
# 56374              False  BTS (방탄소년단) 'Butter' Official MV Credits: Dire...
# 151968             False  BLACKPINK - ‘Pink Venom’ M/VKick in the door W...
# 151773             False  BLACKPINK - ‘Pink Venom’ M/VKick in the door W...

# %%
top_10_most_liked = df.sort_values(by='likes', ascending=False).head(10)
top_10_most_liked
# Out:
#            video_id                               title           publishedAt  \
# 56374   WMweEpGlu_U    BTS (방탄소년단) 'Butter' Official MV  2021-05-21T03:46:13Z
# 3358    gdZLi9oWNZg  BTS (방탄소년단) 'Dynamite' Official MV  2020-08-21T03:58:10Z
# 3137    gdZLi9oWNZg  BTS (방탄소년단) 'Dynamite' Official MV  2020-08-21T03:58:10Z
# 2894    gdZLi9oWNZg  BTS (방탄소년단) 'Dynamite' Official MV  2020-08-21T03:58:10Z
# 2653    gdZLi9oWNZg  BTS (방탄소년단) 'Dynamite' Official MV  2020-08-21T03:58:10Z
# 2418    gdZLi9oWNZg  BTS (방탄소년단) 'Dynamite' Official MV  2020-08-21T03:58:10Z
# 55994   WMweEpGlu_U    BTS (방탄소년단) 'Butter' Official MV  2021-05-21T03:46:13Z
# 2201    gdZLi9oWNZg  BTS (방탄소년단) 'Dynamite' Official MV  2020-08-21T03:58:10Z
# 55791   WMweEpGlu_U    BTS (방탄소년단) 'Butter' Official MV  2021-05-21T03:46:13Z
# 152788  gQlMMD8auMs        BLACKPINK - ‘Pink Venom’ M/V  2022-08-19T04:00:13Z
#
#                        channelId    channelTitle  categoryId  \
# 56374   UC3IZKseVpdzPSBaWxBxundA     HYBE LABELS          10
# 3358    UC3IZKseVpdzPSBaWxBxundA  Big Hit Labels          10
# 3137    UC3IZKseVpdzPSBaWxBxundA  Big Hit Labels          10
# 2894    UC3IZKseVpdzPSBaWxBxundA  Big Hit Labels          10
# 2653    UC3IZKseVpdzPSBaWxBxundA  Big Hit Labels          10
# 2418    UC3IZKseVpdzPSBaWxBxundA  Big Hit Labels          10
# 55994   UC3IZKseVpdzPSBaWxBxundA     HYBE LABELS          10
# 2201    UC3IZKseVpdzPSBaWxBxundA  Big Hit Labels          10
# 55791   UC3IZKseVpdzPSBaWxBxundA     HYBE LABELS          10
# 152788  UCOmHUn--16B90oW2L6FRR3A       BLACKPINK          10
#
#                trending_date  \
# 56374   2021-05-30T00:00:00Z
# 3358    2020-08-28T00:00:00Z
# 3137    2020-08-27T00:00:00Z
# 2894    2020-08-26T00:00:00Z
# 2653    2020-08-25T00:00:00Z
# 2418    2020-08-24T00:00:00Z
# 55994   2021-05-23T00:00:00Z
# 2201    2020-08-23T00:00:00Z
# 55791   2021-05-22T00:00:00Z
# 152788  2022-09-10T00:00:00Z
#
#                                                      tags  view_count  \
# 56374                     BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   264407389
# 3358                      BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   232649205
# 3137                      BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   219110491
# 2894                      BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   208581468
# 2653                      BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   200692965
# 2418                      BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   183414472
# 55994                     BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   166895681
# 2201                      BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   160510938
# 55791                     BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   133484128
# 152788  YG Entertainment|YG|와이지|K-pop|BLACKPINK|블랙핑크|블...   277791741
#
#            likes  dislikes  comment_count  \
# 56374   16021534    150989        6738537
# 3358    15735533    714194        6065230
# 3137    15460822    674291        5810680
# 2894    15246496    646349        5744496
# 2653    14994034    621578        5623570
# 2418    14678048    576852        5748638
# 55994   14202518     51663        5987770
# 2201    14134480    505291        5452026
# 55791   13361198     28528        5594286
# 152788  12993894         0        3534337
#
#                                         thumbnail_link  comments_disabled  \
# 56374   https://i.ytimg.com/vi/WMweEpGlu_U/default.jpg              False
# 3358    https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg              False
# 3137    https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg              False
# 2894    https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg              False
# 2653    https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg              False
# 2418    https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg              False
# 55994   https://i.ytimg.com/vi/WMweEpGlu_U/default.jpg              False
# 2201    https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg              False
# 55791   https://i.ytimg.com/vi/WMweEpGlu_U/default.jpg              False
# 152788  https://i.ytimg.com/vi/gQlMMD8auMs/default.jpg              False
#
#         ratings_disabled                                        description
# 56374              False  BTS (방탄소년단) 'Butter' Official MV Credits: Dire...
# 3358               False  BTS (방탄소년단) 'Dynamite' Official MVCredits:Dire...
# 3137               False  BTS (방탄소년단) 'Dynamite' Official MVCredits:Dire...
# 2894               False  BTS (방탄소년단) 'Dynamite' Official MVCredits:Dire...
# 2653               False  BTS (방탄소년단) 'Dynamite' Official MVCredits:Dire...
# 2418               False  BTS (방탄소년단) 'Dynamite' Official MVCredits:Dire...
# 55994              False  BTS (방탄소년단) 'Butter' Official MV Credits: Dire...
# 2201               False  BTS (방탄소년단) 'Dynamite' Official MVCredits:Dire...
# 55791              False  BTS (방탄소년단) 'Butter' Official MV Credits: Dire...
# 152788             False  BLACKPINK - ‘Pink Venom’ M/VKick in the door W...

# %%
df_sorted_view = df.sort_values(by=['view_count'], ascending=[False])
df_sorted_view
# Out:
#            video_id                                        title  \
# 266187  cc2-4ci4G84                 Discord Loot Boxes are here.
# 266388  cc2-4ci4G84                 Discord Loot Boxes are here.
# 265987  cc2-4ci4G84                 Discord Loot Boxes are here.
# 152788  gQlMMD8auMs                 BLACKPINK - ‘Pink Venom’ M/V
# 152568  gQlMMD8auMs                 BLACKPINK - ‘Pink Venom’ M/V
# ...             ...                                          ...
# 49597   69KrkMpvZdg  Celebrating Luther Vandross's 70th Birthday
# 126641  ZoPJVcHYlU0                         Celebrating Route 66
# 126404  ZoPJVcHYlU0                         Celebrating Route 66
# 200521  LHCTW4pckDo              Live at the Met Gala With Vogue
# 20184   AWXvClaRtsI                  Celebrating Maria Tallchief
#
#                  publishedAt                 channelId   channelTitle  \
# 266187  2024-04-01T17:46:17Z  UCZ5XnGb-3t7jCkXdawN2tkA        Discord
# 266388  2024-04-01T17:46:17Z  UCZ5XnGb-3t7jCkXdawN2tkA        Discord
# 265987  2024-04-01T17:46:17Z  UCZ5XnGb-3t7jCkXdawN2tkA        Discord
# 152788  2022-08-19T04:00:13Z  UCOmHUn--16B90oW2L6FRR3A      BLACKPINK
# 152568  2022-08-19T04:00:13Z  UCOmHUn--16B90oW2L6FRR3A      BLACKPINK
# ...                      ...                       ...            ...
# 49597   2021-04-19T15:00:08Z  UCdq61m8s_48EhJ5OM_MCeGw  GoogleDoodles
# 126641  2022-04-29T16:46:04Z  UCdq61m8s_48EhJ5OM_MCeGw  GoogleDoodles
# 126404  2022-04-29T16:46:04Z  UCdq61m8s_48EhJ5OM_MCeGw  GoogleDoodles
# 200521  2023-05-02T01:36:13Z  UCRXiA3h1no_PFkb1JCP0yMA          Vogue
# 20184   2020-11-14T22:39:13Z  UCdq61m8s_48EhJ5OM_MCeGw  GoogleDoodles
#
#         categoryId         trending_date  \
# 266187          24  2024-04-03T00:00:00Z
# 266388          24  2024-04-04T00:00:00Z
# 265987          24  2024-04-02T00:00:00Z
# 152788          10  2022-09-10T00:00:00Z
# 152568          10  2022-09-09T00:00:00Z
# ...            ...                   ...
# 49597            1  2021-04-21T00:00:00Z
# 126641           1  2022-05-03T00:00:00Z
# 126404           1  2022-05-02T00:00:00Z
# 200521          26  2023-05-07T00:00:00Z
# 20184           10  2020-11-21T00:00:00Z
#
#                                                      tags  view_count  \
# 266187                                             [None]  1407643634
# 266388                                             [None]  1406329649
# 265987                                             [None]   628718636
# 152788  YG Entertainment|YG|와이지|K-pop|BLACKPINK|블랙핑크|블...   277791741
# 152568  YG Entertainment|YG|와이지|K-pop|BLACKPINK|블랙핑크|블...   273162966
# ...                                                   ...         ...
# 49597                                              [None]           0
# 126641                                             [None]           0
# 126404                                             [None]           0
# 200521  vogue|met gala|emma chamberlain|metgala23-live...           0
# 20184                                              [None]           0
#
#            likes  dislikes  comment_count  \
# 266187    126926         0          13987
# 266388    165173         0          17446
# 265987     47460         0           4829
# 152788  12993894         0        3534337
# 152568  12937252         0        3516745
# ...          ...       ...            ...
# 49597          0         0              0
# 126641         0         0              0
# 126404         0         0              0
# 200521     96043         0           1856
# 20184          0         0              0
#
#                                         thumbnail_link  comments_disabled  \
# 266187  https://i.ytimg.com/vi/cc2-4ci4G84/default.jpg              False
# 266388  https://i.ytimg.com/vi/cc2-4ci4G84/default.jpg              False
# 265987  https://i.ytimg.com/vi/cc2-4ci4G84/default.jpg              False
# 152788  https://i.ytimg.com/vi/gQlMMD8auMs/default.jpg              False
# 152568  https://i.ytimg.com/vi/gQlMMD8auMs/default.jpg              False
# ...                                                ...                ...
# 49597   https://i.ytimg.com/vi/69KrkMpvZdg/default.jpg               True
# 126641  https://i.ytimg.com/vi/ZoPJVcHYlU0/default.jpg               True
# 126404  https://i.ytimg.com/vi/ZoPJVcHYlU0/default.jpg               True
# 200521  https://i.ytimg.com/vi/LHCTW4pckDo/default.jpg              False
# 20184   https://i.ytimg.com/vi/AWXvClaRtsI/default.jpg               True
#
#         ratings_disabled                                        description
# 266187             False  Why would we ever bring Loot Boxes into a chat...
# 266388             False  Why would we ever bring Loot Boxes into a chat...
# 265987             False  Why would we ever bring Loot Boxes into a chat...
# 152788             False  BLACKPINK - ‘Pink Venom’ M/VKick in the door W...
# 152568             False  BLACKPINK - ‘Pink Venom’ M/VKick in the door W...
# ...                  ...                                                ...
# 49597               True  Today’s video Doodle, created by Atlanta-based...
# 126641              True  Today’s video Doodle takes you on the ultimate...
# 126404              True  Today’s video Doodle takes you on the ultimate...
# 200521             False  For the third year in a row, Vogue will be hos...
# 20184               True  In honor of Native American Heritage Month in ...
#
# [267987 rows x 16 columns]

# %%
unique_videos_view = df_sorted_view.drop_duplicates(subset='title', keep='first')

unique_videos_view
# Out:
#            video_id                                              title  \
# 266187  cc2-4ci4G84                       Discord Loot Boxes are here.
# 152788  gQlMMD8auMs                       BLACKPINK - ‘Pink Venom’ M/V
# 56374   WMweEpGlu_U                   BTS (방탄소년단) 'Butter' Official MV
# 3358    gdZLi9oWNZg                 BTS (방탄소년단) 'Dynamite' Official MV
# 73564   hdmx71UjBXs                Turn into orbeez - Tutorial #Shorts
# ...             ...                                                ...
# 126865  ZoPJVcHYlU0                               Celebrating Route 66
# 65504   ifJYb2An7wE  Gay And Not Proud - Daniel Howell | YouTube Pr...
# 65528   kmk5vciFbek  Demi Lovato performs their greatest hits this ...
# 74492   Hb3rmh-_FMw            Introducing the shorter side of YouTube
# 80754   BxOEj8ZeX2g                       Tim Bergling's 32nd Birthday
#
#                  publishedAt                 channelId    channelTitle  \
# 266187  2024-04-01T17:46:17Z  UCZ5XnGb-3t7jCkXdawN2tkA         Discord
# 152788  2022-08-19T04:00:13Z  UCOmHUn--16B90oW2L6FRR3A       BLACKPINK
# 56374   2021-05-21T03:46:13Z  UC3IZKseVpdzPSBaWxBxundA     HYBE LABELS
# 3358    2020-08-21T03:58:10Z  UC3IZKseVpdzPSBaWxBxundA  Big Hit Labels
# 73564   2021-07-03T04:04:57Z  UCt8z2S30Wl-GQEluFVM8NUw          FFUNTV
# ...                      ...                       ...             ...
# 126865  2022-04-29T16:46:04Z  UCdq61m8s_48EhJ5OM_MCeGw   GoogleDoodles
# 65504   2021-06-25T21:04:38Z  UCGjylN-4QCpn8XJ1uY-UOgA   Daniel Howell
# 65528   2021-06-26T00:07:19Z  UCZkURf9tDolFOeuw_4RD7XQ     Demi Lovato
# 74492   2021-08-10T15:04:25Z  UCBR8-60-B28hp2BmDPdntcQ         YouTube
# 80754   2021-09-07T12:00:08Z  UCdq61m8s_48EhJ5OM_MCeGw   GoogleDoodles
#
#         categoryId         trending_date  \
# 266187          24  2024-04-03T00:00:00Z
# 152788          10  2022-09-10T00:00:00Z
# 56374           10  2021-05-30T00:00:00Z
# 3358            10  2020-08-28T00:00:00Z
# 73564           24  2021-08-08T00:00:00Z
# ...            ...                   ...
# 126865           1  2022-05-04T00:00:00Z
# 65504           24  2021-06-29T00:00:00Z
# 65528           24  2021-06-29T00:00:00Z
# 74492           27  2021-08-13T00:00:00Z
# 80754            1  2021-09-13T00:00:00Z
#
#                                                      tags  view_count  \
# 266187                                             [None]  1407643634
# 152788  YG Entertainment|YG|와이지|K-pop|BLACKPINK|블랙핑크|블...   277791741
# 56374                     BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   264407389
# 3358                      BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   232649205
# 73564                                              [None]   206202284
# ...                                                   ...         ...
# 126865                                             [None]           0
# 65504   Pride|Pride 2021|YouTube Pride|YouTube Pride 2...           0
# 65528   Pride|Pride 2021|YouTube Pride|YouTube Pride 2...           0
# 74492                                              [None]           0
# 80754                                              [None]           0
#
#            likes  dislikes  comment_count  \
# 266187    126926         0          13987
# 152788  12993894         0        3534337
# 56374   16021534    150989        6738537
# 3358    15735533    714194        6065230
# 73564    6840430    240769           2826
# ...          ...       ...            ...
# 126865         0         0              0
# 65504          0         0           1739
# 65528          0         0            147
# 74492      22030      1604              0
# 80754          0         0              0
#
#                                         thumbnail_link  comments_disabled  \
# 266187  https://i.ytimg.com/vi/cc2-4ci4G84/default.jpg              False
# 152788  https://i.ytimg.com/vi/gQlMMD8auMs/default.jpg              False
# 56374   https://i.ytimg.com/vi/WMweEpGlu_U/default.jpg              False
# 3358    https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg              False
# 73564   https://i.ytimg.com/vi/hdmx71UjBXs/default.jpg              False
# ...                                                ...                ...
# 126865  https://i.ytimg.com/vi/ZoPJVcHYlU0/default.jpg               True
# 65504   https://i.ytimg.com/vi/ifJYb2An7wE/default.jpg              False
# 65528   https://i.ytimg.com/vi/kmk5vciFbek/default.jpg              False
# 74492   https://i.ytimg.com/vi/Hb3rmh-_FMw/default.jpg               True
# 80754   https://i.ytimg.com/vi/BxOEj8ZeX2g/default.jpg               True
#
#         ratings_disabled                                        description
# 266187             False  Why would we ever bring Loot Boxes into a chat...
# 152788             False  BLACKPINK - ‘Pink Venom’ M/VKick in the door W...
# 56374              False  BTS (방탄소년단) 'Butter' Official MV Credits: Dire...
# 3358               False  BTS (방탄소년단) 'Dynamite' Official MVCredits:Dire...
# 73564              False  Turn into orbeez - Tutorial #ShortsHey guys! W...
# ...                  ...                                                ...
# 126865              True  Today’s video Doodle takes you on the ultimate...
# 65504               True  On June 25, join Daniel Howell as he celebrate...
# 65528               True  On June 25, celebrate Pride 2021 with Demi Lov...
# 74492              False  *****EPILEPSY WARNING ********Watch and create...
# 80754               True  Today's video Doodle celebrates the 32nd birth...
#
# [48361 rows x 16 columns]

# %%
df_sorted_likes = df.sort_values(by=['likes'], ascending=[False])
df_sorted_likes
# Out:
#            video_id                                              title  \
# 56374   WMweEpGlu_U                   BTS (방탄소년단) 'Butter' Official MV
# 3358    gdZLi9oWNZg                 BTS (방탄소년단) 'Dynamite' Official MV
# 3137    gdZLi9oWNZg                 BTS (방탄소년단) 'Dynamite' Official MV
# 2894    gdZLi9oWNZg                 BTS (방탄소년단) 'Dynamite' Official MV
# 2653    gdZLi9oWNZg                 BTS (방탄소년단) 'Dynamite' Official MV
# ...             ...                                                ...
# 28118   k5XukvUA1Nk           Kylie Jenner: Christmas Decorations 2020
# 217710  a4sjgbrnus8   (NO REMATCH!!) Crawford is the SUPERIOR Fighter!
# 217735  _APQSQtP0bE  I CANNOT BELIEVE WHAT I JUST WATCHED!! TERRENC...
# 107828  jJX5CrTg0F4     Eliminatorias | Ecuador  1-1 Brasil | Fecha 15
# 177394  KLaZZHQvw24   TAEYANG - 'VIBE (feat. Jimin of BTS)' M/V TEASER
#
#                  publishedAt                 channelId        channelTitle  \
# 56374   2021-05-21T03:46:13Z  UC3IZKseVpdzPSBaWxBxundA         HYBE LABELS
# 3358    2020-08-21T03:58:10Z  UC3IZKseVpdzPSBaWxBxundA      Big Hit Labels
# 3137    2020-08-21T03:58:10Z  UC3IZKseVpdzPSBaWxBxundA      Big Hit Labels
# 2894    2020-08-21T03:58:10Z  UC3IZKseVpdzPSBaWxBxundA      Big Hit Labels
# 2653    2020-08-21T03:58:10Z  UC3IZKseVpdzPSBaWxBxundA      Big Hit Labels
# ...                      ...                       ...                 ...
# 28118   2020-12-26T04:07:01Z  UCWkYXtnAuu7VTLPwUcRSB6A        Kylie Jenner
# 217710  2023-07-30T14:20:59Z  UCYxVAOXX7beQCyXb4OW_Z2g  ShowBizz The Adult
# 217735  2023-07-30T05:27:26Z  UCShLzlyKXSC32InQzFk3fOQ           Paulie TV
# 107828  2022-01-28T01:35:44Z  UCzU8-lZlRfkV3nj0RzAZdrQ            CONMEBOL
# 177394  2023-01-11T05:00:13Z  UCg8ZzloDPTrOiGztK0C9txQ       THEBLACKLABEL
#
#         categoryId         trending_date  \
# 56374           10  2021-05-30T00:00:00Z
# 3358            10  2020-08-28T00:00:00Z
# 3137            10  2020-08-27T00:00:00Z
# 2894            10  2020-08-26T00:00:00Z
# 2653            10  2020-08-25T00:00:00Z
# ...            ...                   ...
# 28118           22  2021-01-03T00:00:00Z
# 217710          17  2023-08-03T00:00:00Z
# 217735          17  2023-08-03T00:00:00Z
# 107828          17  2022-01-29T00:00:00Z
# 177394          10  2023-01-12T00:00:00Z
#
#                                                      tags  view_count  \
# 56374                     BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   264407389
# 3358                      BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   232649205
# 3137                      BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   219110491
# 2894                      BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   208581468
# 2653                      BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   200692965
# ...                                                   ...         ...
# 28118                                              [None]     8690969
# 217710                                             [None]      352436
# 217735                                             [None]      226958
# 107828  fútbol|pelota|gol|copa|libertadores|sudamerica...     1643210
# 177394  TAEYANG|SOL|BIGBANG|PRAYER|SOLARL|태양|빅뱅|VIBE|바...     2959075
#
#            likes  dislikes  comment_count  \
# 56374   16021534    150989        6738537
# 3358    15735533    714194        6065230
# 3137    15460822    674291        5810680
# 2894    15246496    646349        5744496
# 2653    14994034    621578        5623570
# ...          ...       ...            ...
# 28118          0         0          14996
# 217710         0         0           8064
# 217735         0         0           3293
# 107828         0         0           4375
# 177394         0         0          18870
#
#                                         thumbnail_link  comments_disabled  \
# 56374   https://i.ytimg.com/vi/WMweEpGlu_U/default.jpg              False
# 3358    https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg              False
# 3137    https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg              False
# 2894    https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg              False
# 2653    https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg              False
# ...                                                ...                ...
# 28118   https://i.ytimg.com/vi/k5XukvUA1Nk/default.jpg              False
# 217710  https://i.ytimg.com/vi/a4sjgbrnus8/default.jpg              False
# 217735  https://i.ytimg.com/vi/_APQSQtP0bE/default.jpg              False
# 107828  https://i.ytimg.com/vi/jJX5CrTg0F4/default.jpg              False
# 177394  https://i.ytimg.com/vi/KLaZZHQvw24/default.jpg              False
#
#         ratings_disabled                                        description
# 56374              False  BTS (방탄소년단) 'Butter' Official MV Credits: Dire...
# 3358               False  BTS (방탄소년단) 'Dynamite' Official MVCredits:Dire...
# 3137               False  BTS (방탄소년단) 'Dynamite' Official MVCredits:Dire...
# 2894               False  BTS (방탄소년단) 'Dynamite' Official MVCredits:Dire...
# 2653               False  BTS (방탄소년단) 'Dynamite' Official MVCredits:Dire...
# ...                  ...                                                ...
# 28118               True  Stormi and I take you on a tour of my Christma...
# 217710              True            #errolspence #terencecrawford #showbizz
# 217735              True                HOLY!!!!!!!!FOLLOW @PAULIE.TV ON IG
# 107828              True  En un partido muy parejo, la Tri y la Canarinh...
# 177394              True  TAEYANG - 'VIBE (feat. Jimin of BTS)' M/V TEAS...
#
# [267987 rows x 16 columns]

# %%
df = unique_videos_view
df
# Out:
#            video_id                                              title  \
# 266187  cc2-4ci4G84                       Discord Loot Boxes are here.
# 152788  gQlMMD8auMs                       BLACKPINK - ‘Pink Venom’ M/V
# 56374   WMweEpGlu_U                   BTS (방탄소년단) 'Butter' Official MV
# 3358    gdZLi9oWNZg                 BTS (방탄소년단) 'Dynamite' Official MV
# 73564   hdmx71UjBXs                Turn into orbeez - Tutorial #Shorts
# ...             ...                                                ...
# 126865  ZoPJVcHYlU0                               Celebrating Route 66
# 65504   ifJYb2An7wE  Gay And Not Proud - Daniel Howell | YouTube Pr...
# 65528   kmk5vciFbek  Demi Lovato performs their greatest hits this ...
# 74492   Hb3rmh-_FMw            Introducing the shorter side of YouTube
# 80754   BxOEj8ZeX2g                       Tim Bergling's 32nd Birthday
#
#                  publishedAt                 channelId    channelTitle  \
# 266187  2024-04-01T17:46:17Z  UCZ5XnGb-3t7jCkXdawN2tkA         Discord
# 152788  2022-08-19T04:00:13Z  UCOmHUn--16B90oW2L6FRR3A       BLACKPINK
# 56374   2021-05-21T03:46:13Z  UC3IZKseVpdzPSBaWxBxundA     HYBE LABELS
# 3358    2020-08-21T03:58:10Z  UC3IZKseVpdzPSBaWxBxundA  Big Hit Labels
# 73564   2021-07-03T04:04:57Z  UCt8z2S30Wl-GQEluFVM8NUw          FFUNTV
# ...                      ...                       ...             ...
# 126865  2022-04-29T16:46:04Z  UCdq61m8s_48EhJ5OM_MCeGw   GoogleDoodles
# 65504   2021-06-25T21:04:38Z  UCGjylN-4QCpn8XJ1uY-UOgA   Daniel Howell
# 65528   2021-06-26T00:07:19Z  UCZkURf9tDolFOeuw_4RD7XQ     Demi Lovato
# 74492   2021-08-10T15:04:25Z  UCBR8-60-B28hp2BmDPdntcQ         YouTube
# 80754   2021-09-07T12:00:08Z  UCdq61m8s_48EhJ5OM_MCeGw   GoogleDoodles
#
#         categoryId         trending_date  \
# 266187          24  2024-04-03T00:00:00Z
# 152788          10  2022-09-10T00:00:00Z
# 56374           10  2021-05-30T00:00:00Z
# 3358            10  2020-08-28T00:00:00Z
# 73564           24  2021-08-08T00:00:00Z
# ...            ...                   ...
# 126865           1  2022-05-04T00:00:00Z
# 65504           24  2021-06-29T00:00:00Z
# 65528           24  2021-06-29T00:00:00Z
# 74492           27  2021-08-13T00:00:00Z
# 80754            1  2021-09-13T00:00:00Z
#
#                                                      tags  view_count  \
# 266187                                             [None]  1407643634
# 152788  YG Entertainment|YG|와이지|K-pop|BLACKPINK|블랙핑크|블...   277791741
# 56374                     BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   264407389
# 3358                      BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄   232649205
# 73564                                              [None]   206202284
# ...                                                   ...         ...
# 126865                                             [None]           0
# 65504   Pride|Pride 2021|YouTube Pride|YouTube Pride 2...           0
# 65528   Pride|Pride 2021|YouTube Pride|YouTube Pride 2...           0
# 74492                                              [None]           0
# 80754                                              [None]           0
#
#            likes  dislikes  comment_count  \
# 266187    126926         0          13987
# 152788  12993894         0        3534337
# 56374   16021534    150989        6738537
# 3358    15735533    714194        6065230
# 73564    6840430    240769           2826
# ...          ...       ...            ...
# 126865         0         0              0
# 65504          0         0           1739
# 65528          0         0            147
# 74492      22030      1604              0
# 80754          0         0              0
#
#                                         thumbnail_link  comments_disabled  \
# 266187  https://i.ytimg.com/vi/cc2-4ci4G84/default.jpg              False
# 152788  https://i.ytimg.com/vi/gQlMMD8auMs/default.jpg              False
# 56374   https://i.ytimg.com/vi/WMweEpGlu_U/default.jpg              False
# 3358    https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg              False
# 73564   https://i.ytimg.com/vi/hdmx71UjBXs/default.jpg              False
# ...                                                ...                ...
# 126865  https://i.ytimg.com/vi/ZoPJVcHYlU0/default.jpg               True
# 65504   https://i.ytimg.com/vi/ifJYb2An7wE/default.jpg              False
# 65528   https://i.ytimg.com/vi/kmk5vciFbek/default.jpg              False
# 74492   https://i.ytimg.com/vi/Hb3rmh-_FMw/default.jpg               True
# 80754   https://i.ytimg.com/vi/BxOEj8ZeX2g/default.jpg               True
#
#         ratings_disabled                                        description
# 266187             False  Why would we ever bring Loot Boxes into a chat...
# 152788             False  BLACKPINK - ‘Pink Venom’ M/VKick in the door W...
# 56374              False  BTS (방탄소년단) 'Butter' Official MV Credits: Dire...
# 3358               False  BTS (방탄소년단) 'Dynamite' Official MVCredits:Dire...
# 73564              False  Turn into orbeez - Tutorial #ShortsHey guys! W...
# ...                  ...                                                ...
# 126865              True  Today’s video Doodle takes you on the ultimate...
# 65504               True  On June 25, join Daniel Howell as he celebrate...
# 65528               True  On June 25, celebrate Pride 2021 with Demi Lov...
# 74492              False  *****EPILEPSY WARNING ********Watch and create...
# 80754               True  Today's video Doodle celebrates the 32nd birth...
#
# [48361 rows x 16 columns]

# %%
# # Question: Which videos are currently trending?

current_trending_videos = df[df['trending_date'] == df['trending_date'].max()]
current_trending_videos
# Out:
#            video_id                                              title  \
# 267919  mKdjycj-7eE                 Stop This Train, Win a Lamborghini
# 267836  erLbbextvlY                       7 Days Stranded On An Island
# 267968  2wA_b6YHjqQ                         BABYMONSTER - ‘SHEESH’ M/V
# 267963  DiHUEWBRQEI              TXT (투모로우바이투게더) 'Deja Vu' Official MV
# 267952  m7sp-FTeZWE                         skibidi toilet 72 (part 2)
# ...             ...                                                ...
# 267944  FIcltYpGuQU  Rep. Lauren Boebert hospitalized with acute bl...
# 267841  liNJPPqo0c8  WBB Postgame: (Iowa) South Carolina Press Conf...
# 267810  yvB5gQVyVtI  Detailed Look! All New 2025 6th Gen Toyota 4Ru...
# 267856  Ii4jXrMqXf4  17,000 units of cargo being rerouted to the pe...
# 267805  FTU5rZBJu28  USWNT vs. Canada HIGHLIGHTS | 2024 SheBelieves...
#
#                  publishedAt                 channelId  \
# 267919  2024-03-16T16:00:00Z  UCX6OQ3DkcsbYNE6H8uQQuVA
# 267836  2024-03-30T16:00:01Z  UCX6OQ3DkcsbYNE6H8uQQuVA
# 267968  2024-03-31T15:00:08Z  UCqwUnggBBct-AY2lAdI88jQ
# 267963  2024-04-01T08:58:06Z  UC3IZKseVpdzPSBaWxBxundA
# 267952  2024-04-01T13:00:07Z  UCsSsgPaZ2GSmO6il8Cb5iGA
# ...                      ...                       ...
# 267944  2024-04-03T14:56:01Z  UCkRP0nS2qERsw-U-OTLbI0A
# 267841  2024-04-07T23:57:01Z  UCIJ8yiBEYi7OSDtJmTZnUZQ
# 267810  2024-04-10T02:15:02Z  UCVaQcr-1Ct5xIzpjF8P9VzQ
# 267856  2024-04-08T01:57:47Z  UC4DGZQHLsQRK3v8lKTGu_Uw
# 267805  2024-04-10T01:26:52Z  UCk1pcWQ5E19g0Cgp4c1eI1w
#
#                     channelTitle  categoryId         trending_date  \
# 267919                   MrBeast          24  2024-04-11T00:00:00Z
# 267836                   MrBeast          24  2024-04-11T00:00:00Z
# 267968               BABYMONSTER          22  2024-04-11T00:00:00Z
# 267963               HYBE LABELS          10  2024-04-11T00:00:00Z
# 267952              DaFuq!?Boom!          24  2024-04-11T00:00:00Z
# ...                          ...         ...                   ...
# 267944              FOX31 Denver          25  2024-04-11T00:00:00Z
# 267841  South Carolina Gamecocks          17  2024-04-11T00:00:00Z
# 267810                   TRD JON           2  2024-04-11T00:00:00Z
# 267856                 WJCL News          25  2024-04-11T00:00:00Z
# 267805               U.S. Soccer          17  2024-04-11T00:00:00Z
#
#                                                      tags  view_count  \
# 267919                                             [None]   115271012
# 267836                                             [None]   108502278
# 267968  BABYMONSTER|베이비몬스터|베몬|BABYMON|BAEMON|하람|아현|루카|...   101967017
# 267963                       HYBE|HYBE LABELS|하이브|하이브레이블즈    45768299
# 267952  sfm animation|skibidi toilet vs cameramen|skib...    29731675
# ...                                                   ...         ...
# 267944                    denver|colorado|news|kdvr|fox31      131578
# 267841                                             [None]      126862
# 267810                                             [None]      109587
# 267856                                           Savannah      100820
# 267805  Adriana Leon|Alyssa Naeher|Crystal Dunn|Emily ...      100795
#
#           likes  dislikes  comment_count  \
# 267919  4276347         0         126646
# 267836  4613204         0         126888
# 267968  2291274         0         165478
# 267963   965451         0         163965
# 267952  1212478         0         105448
# ...         ...       ...            ...
# 267944     2299         0           3231
# 267841     2909         0            525
# 267810     3438         0            769
# 267856      751         0              0
# 267805      980         0            219
#
#                                         thumbnail_link  comments_disabled  \
# 267919  https://i.ytimg.com/vi/mKdjycj-7eE/default.jpg              False
# 267836  https://i.ytimg.com/vi/erLbbextvlY/default.jpg              False
# 267968  https://i.ytimg.com/vi/2wA_b6YHjqQ/default.jpg              False
# 267963  https://i.ytimg.com/vi/DiHUEWBRQEI/default.jpg              False
# 267952  https://i.ytimg.com/vi/m7sp-FTeZWE/default.jpg              False
# ...                                                ...                ...
# 267944  https://i.ytimg.com/vi/FIcltYpGuQU/default.jpg              False
# 267841  https://i.ytimg.com/vi/liNJPPqo0c8/default.jpg              False
# 267810  https://i.ytimg.com/vi/yvB5gQVyVtI/default.jpg              False
# 267856  https://i.ytimg.com/vi/Ii4jXrMqXf4/default.jpg               True
# 267805  https://i.ytimg.com/vi/FTU5rZBJu28/default.jpg              False
#
#         ratings_disabled                                        description
# 267919             False  I still can’t believe what happened in this vi...
# 267836             False  I can’t believe we actually did thisSend money...
# 267968             False  SHEESHDa la lun dunDa la lun dunDa la lun dunB...
# 267963             False  TXT (투모로우바이투게더) 'Deja Vu' Official MVCredits:W...
# 267952             False  g-toilet battles with astrofull-screen version...
# ...                  ...                                                ...
# 267944             False  Rep. Lauren Boebert, of Colorado’s 3rd distric...
# 267841             False  South Carolina Head Coach Dawn Staley, Senior ...
# 267810             False  It's here! The all new 2025 6th Generation Toy...
# 267856             False  17,000 units of cargo being rerouted to the pe...
# 267805             False  The USWNT won the 2024 SheBelieves Cup in pena...
#
# [199 rows x 16 columns]

# %%
# Question: # How long does it take for a video to become trending after being published?


# Assuming df is your DataFrame containing the dataset
# Convert 'publishedAt' and 'trending_date' columns to datetime format
df['publishedAt'] = pd.to_datetime(df['publishedAt'])
df['trending_date'] = pd.to_datetime(df['trending_date'])

# Calculate time to trend
df['time_to_trend'] = df['trending_date'] - df['publishedAt']

# Find average or median time to trend
average_time_to_trend = df['time_to_trend'].mean()
median_time_to_trend = df['time_to_trend'].median()

print("Average time to trend:", average_time_to_trend)
print("Median time to trend:", median_time_to_trend)
# Out:
# Average time to trend: 5 days 12:45:07.435805711
# Median time to trend: 5 days 08:59:43
# /var/folders/03/4fzp3dpd36s1z9wlxm8hzlv00000gn/T/ipykernel_76500/1756668958.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['publishedAt'] = pd.to_datetime(df['publishedAt'])
# /var/folders/03/4fzp3dpd36s1z9wlxm8hzlv00000gn/T/ipykernel_76500/1756668958.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['trending_date'] = pd.to_datetime(df['trending_date'])
# /var/folders/03/4fzp3dpd36s1z9wlxm8hzlv00000gn/T/ipykernel_76500/1756668958.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['time_to_trend'] = df['trending_date'] - df['publishedAt']

# %%
# # Question: # Are there specific categories that tend to trend more frequently?

df['tags'] = df['tags'].str.split('|')
# Create a list of all tags
all_tags = [tag for sublist in df['tags'] for tag in sublist]
# Count occurrences of each tag
tag_counts = pd.Series(all_tags).value_counts()
# Display the top 10 most common tags
print("Top 10 most common tags among trending videos:")
print(tag_counts.head(10))
# Out:
# Top 10 most common tags among trending videos:
# [None]             8021
# funny              2667
# comedy             1701
# minecraft          1636
# challenge          1118
# gaming              930
# vlog                912
# news                774
# NBA                 727
# family friendly     704
# Name: count, dtype: int64
# /var/folders/03/4fzp3dpd36s1z9wlxm8hzlv00000gn/T/ipykernel_76500/3251651.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'] = df['tags'].str.split('|')

# %%
# Assuming df is your DataFrame containing the dataset
# Select the columns for likes, dislikes, and comments
likes_dislikes_comments = df[['likes', 'dislikes', 'comment_count']]

# Calculate the correlation matrix
correlation_matrix = likes_dislikes_comments.corr()

print("Correlation matrix between likes, dislikes, and comments:")
print(correlation_matrix)
# Out:
# Correlation matrix between likes, dislikes, and comments:
#                   likes  dislikes  comment_count
# likes          1.000000  0.465583       0.683727
# dislikes       0.465583  1.000000       0.466269
# comment_count  0.683727  0.466269       1.000000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing the dataset
# Select the columns for likes, dislikes, and comments
likes_dislikes_comments = df[['likes', 'dislikes', 'comment_count']]

# Calculate the correlation matrix
correlation_matrix = likes_dislikes_comments.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix between Likes, Dislikes, and Comments')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing the dataset
# Select the columns for likes and comments
likes_comments = df[['likes', 'comment_count']]

# Plot the relationship between likes and comments
plt.figure(figsize=(8, 6))
plt.plot(likes_comments['likes'], likes_comments['comment_count'], marker='o', linestyle='', markersize=5, alpha=0.5)
plt.title('Relationship between Likes and Comments')
plt.xlabel('Likes')
plt.ylabel('Comments')
plt.grid(True)
plt.show()

# %%
#  Do videos with more likes tend to have more views?

# Assuming df is your DataFrame containing the dataset
# Select the columns for likes and views
likes_views = df[['likes', 'view_count']]

# Calculate the correlation coefficient
correlation_coefficient = likes_views.corr().iloc[0, 1]

print("Correlation coefficient between likes and views:", correlation_coefficient)
print("This indicates a strong positive correlation between likes and view count.")
# Out:
# Correlation coefficient between likes and views: 0.6301570854051254
# This indicates a strong positive correlation between likes and view count.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example correlation coefficient
correlation_coefficient = 0.8375824158274177

# Create a scatter plot to visualize the correlation coefficient
plt.scatter(0, correlation_coefficient)
plt.title('Correlation Coefficient')
plt.xlabel('Data')
plt.ylabel('Correlation Coefficient')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
# How do likes and comments vary based on the time of publishing?


# Assuming df is your DataFrame containing the dataset
# Convert 'publishedAt' column to datetime format
df['publishedAt'] = pd.to_datetime(df['publishedAt'])

# Extract hour of the day from 'publishedAt'
df['hour_of_publishing'] = df['publishedAt'].dt.hour

# Group by hour of publishing and calculate average likes and comments
likes_comments_by_hour = df.groupby('hour_of_publishing')[['likes', 'comment_count']].mean()

likes_comments_by_hour

# print("Average likes and comments based on the time of publishing (hour of the day):")
# print(likes_comments_by_hour)
# Out:
# /var/folders/03/4fzp3dpd36s1z9wlxm8hzlv00000gn/T/ipykernel_76500/3539095290.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['publishedAt'] = pd.to_datetime(df['publishedAt'])
# /var/folders/03/4fzp3dpd36s1z9wlxm8hzlv00000gn/T/ipykernel_76500/3539095290.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour_of_publishing'] = df['publishedAt'].dt.hour
#                             likes  comment_count
# hour_of_publishing
# 0                   115858.725922    7255.293244
# 1                    92470.500943    6688.684475
# 2                    71589.575591    8017.000000
# 3                   159252.730860   25854.333070
# 4                   236290.218972   23503.998670
# 5                   152253.484751   11249.609149
# 6                   116166.612903    9131.814516
# 7                   138670.890909    7670.875325
# 8                   221938.643182   24361.947727
# 9                   348082.305141   42127.114428
# 10                  124869.524558    6240.801572
# 11                  129022.956193    6816.685801
# 12                  111633.939788    7637.685924
# 13                   94711.877968    6197.152422
# 14                   88440.837504    5809.549236
# 15                  137562.677878   10036.502458
# 16                  110134.176563    6323.333333
# 17                  105345.529140    6561.634531
# 18                   98464.660077    6495.511798
# 19                  105162.952335    6854.743515
# 20                  117659.369499    7032.953645
# 21                  105974.095376    6306.663295
# 22                   83780.321456    5665.591402
# 23                   94834.627025    6335.517353

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing the dataset
# Convert 'publishedAt' column to datetime format
df['publishedAt'] = pd.to_datetime(df['publishedAt'])

# Extract hour of the day from 'publishedAt'
df['hour_of_publishing'] = df['publishedAt'].dt.hour

# Group by hour of publishing and calculate average likes and comments
likes_comments_by_hour = df.groupby('hour_of_publishing')[['likes', 'comment_count']].mean()

# Plot
plt.figure(figsize=(10, 6))

# Likes
plt.plot(likes_comments_by_hour.index, likes_comments_by_hour['likes'], label='Average Likes', marker='o', color='b')

# Comments
plt.plot(likes_comments_by_hour.index, likes_comments_by_hour['comment_count'], label='Average Comments', marker='o', color='r')

# Title and labels
plt.title('Average Likes and Comments by Hour of Publishing')
plt.xlabel('Hour of Publishing')
plt.ylabel('Average Count')
plt.xticks(range(24))  # Assuming 24 hours in a day
plt.grid(True)

# Legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/03/4fzp3dpd36s1z9wlxm8hzlv00000gn/T/ipykernel_76500/742685545.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['publishedAt'] = pd.to_datetime(df['publishedAt'])
# /var/folders/03/4fzp3dpd36s1z9wlxm8hzlv00000gn/T/ipykernel_76500/742685545.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour_of_publishing'] = df['publishedAt'].dt.hour

# %%
# Audience Interaction:
# Are there any patterns in viewer engagement based on the video's category?
# How do comments vary depending on whether comments are enabled or disabled?
# Is there a relationship between the number of comments and the presence of specific tags?

# %%
#Do videos with longer descriptions tend to have higher engagement?

# %%
# Calculate description length in terms of number of characters
df['description_length'] = df['description'].str.len()
df['description_length']
# Out:
# /var/folders/03/4fzp3dpd36s1z9wlxm8hzlv00000gn/T/ipykernel_76500/2973486073.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['description_length'] = df['description'].str.len()
# 266187     100.0
# 152788    2279.0
# 56374     2264.0
# 3358      1929.0
# 73564      248.0
#            ...
# 126865     769.0
# 65504     2003.0
# 65528     1904.0
# 74492       79.0
# 80754      562.0
# Name: description_length, Length: 48361, dtype: float64

# %%
# Remove rows with NaN values in the 'description_length' column
df = df.dropna(subset=['description_length'])

# Group videos into categories based on description length
# You can adjust the bins and labels according to your preference
df['description_category'] = pd.cut(df['description_length'], bins=[10, 1500, 3500, float('inf')],
                                     labels=['Short', 'Medium', 'Long'])
df['description_category']
# Out:
# 266187     Short
# 152788    Medium
# 56374     Medium
# 3358      Medium
# 73564      Short
#            ...
# 126865     Short
# 65504     Medium
# 65528     Medium
# 74492      Short
# 80754      Short
# Name: description_category, Length: 47454, dtype: category
# Categories (3, object): ['Short' < 'Medium' < 'Long']

# %%
# Calculate average engagement metrics for each category
engagement_by_description = df.groupby('description_category').agg({
    'view_count': 'mean',
    'likes': 'mean',
    'dislikes': 'mean',
    'comment_count': 'mean'
}).reset_index()
engagement_by_description
# Out:
# /var/folders/03/4fzp3dpd36s1z9wlxm8hzlv00000gn/T/ipykernel_76500/3121741903.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   engagement_by_description = df.groupby('description_category').agg({
#   description_category    view_count          likes     dislikes  \
# 0                Short  2.428045e+06  109475.065753  1019.302392
# 1               Medium  3.356293e+06  144997.759210  1574.500893
# 2                 Long  2.895585e+06  134368.031587  1262.694915
#
#    comment_count
# 0    7872.597915
# 1   13548.048225
# 2    9128.699538

# %%
# Visualize relationship between description length and engagement metrics
plt.figure(figsize=(10, 6))
sns.barplot(x='description_category', y='view_count', data=engagement_by_description)
plt.title('Average Views by Description Length')
plt.xlabel('Description Length (Characters)')
plt.ylabel('Average Views')
plt.show()
# Out:
# /opt/miniconda3/envs/myenv/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Filter the DataFrame to include only rows where view count is less than 0.5 * 1e8
filtered_df = df[df['view_count'] < 0.2 * 1e8]

# Display the filtered DataFrame
filtered_df
# Out:
#            video_id                                              title  \
# 204547  bef8QLNHubw         Bad Bunny - WHERE SHE GOES (Video Oficial)
# 17398   BInk1AoBHrY  Live: Joe Biden, Kamala Harris Address The Nat...
# 40177   60g72d4Nqss  BTS Performs 'Fix You' (Coldplay Cover) | MTV ...
# 3347    G1mPnQM5hQ0                  Giving JoJo Siwa A FULL MAKEOVER!
# 77387   x_me3xsvDgk           Marvel Studios’ Eternals | Final Trailer
# ...             ...                                                ...
# 126865  ZoPJVcHYlU0                               Celebrating Route 66
# 65504   ifJYb2An7wE  Gay And Not Proud - Daniel Howell | YouTube Pr...
# 65528   kmk5vciFbek  Demi Lovato performs their greatest hits this ...
# 74492   Hb3rmh-_FMw            Introducing the shorter side of YouTube
# 80754   BxOEj8ZeX2g                       Tim Bergling's 32nd Birthday
#
#                      publishedAt                 channelId  \
# 204547 2023-05-19 00:00:08+00:00  UCmBA_wu8xGg1OfOkfW13Q0Q
# 17398  2020-11-08 03:09:03+00:00  UCeY0bbntWzzVIaj2z3QigXg
# 40177  2021-02-24 04:49:29+00:00  UCuwUfM8E79h2sqp34Fut6kw
# 3347   2020-08-21 19:00:06+00:00  UCucot-Zp428OwkyRm2I7v2Q
# 77387  2021-08-19 07:00:05+00:00  UCvC4D8onUfXzvjTOM-dBfEA
# ...                          ...                       ...
# 126865 2022-04-29 16:46:04+00:00  UCdq61m8s_48EhJ5OM_MCeGw
# 65504  2021-06-25 21:04:38+00:00  UCGjylN-4QCpn8XJ1uY-UOgA
# 65528  2021-06-26 00:07:19+00:00  UCZkURf9tDolFOeuw_4RD7XQ
# 74492  2021-08-10 15:04:25+00:00  UCBR8-60-B28hp2BmDPdntcQ
# 80754  2021-09-07 12:00:08+00:00  UCdq61m8s_48EhJ5OM_MCeGw
#
#                 channelTitle  categoryId             trending_date  \
# 204547             Bad Bunny          10 2023-05-27 00:00:00+00:00
# 17398               NBC News          25 2020-11-08 00:00:00+00:00
# 40177                 MTV UK          24 2021-03-04 00:00:00+00:00
# 3347           James Charles          24 2020-08-28 00:00:00+00:00
# 77387   Marvel Entertainment          24 2021-08-27 00:00:00+00:00
# ...                      ...         ...                       ...
# 126865         GoogleDoodles           1 2022-05-04 00:00:00+00:00
# 65504          Daniel Howell          24 2021-06-29 00:00:00+00:00
# 65528            Demi Lovato          24 2021-06-29 00:00:00+00:00
# 74492                YouTube          27 2021-08-13 00:00:00+00:00
# 80754          GoogleDoodles           1 2021-09-13 00:00:00+00:00
#
#                                                      tags  view_count  \
# 204547  [bad bunny, where she goes, where she goes bad...    19989097
# 17398   [nbc, news, news nbc, nbc live, live news, new...    19983734
# 40177   [mtv uk, official, mtv international, MTV EMA,...    19983633
# 3347    [james, james charles, makeup artist, mua, cov...    19977004
# 77387                                    [marvel, comics]    19950757
# ...                                                   ...         ...
# 126865                                           [[None]]           0
# 65504   [Pride, Pride 2021, YouTube Pride, YouTube Pri...           0
# 65528   [Pride, Pride 2021, YouTube Pride, YouTube Pri...           0
# 74492                                            [[None]]           0
# 80754                                            [[None]]           0
#
#           likes  dislikes  comment_count  \
# 204547   867429         0          30957
# 17398    202923     18225           3718
# 40177   1777878     26411         200504
# 3347    1124214     43996          89584
# 77387    621680     11742          38208
# ...         ...       ...            ...
# 126865        0         0              0
# 65504         0         0           1739
# 65528         0         0            147
# 74492     22030      1604              0
# 80754         0         0              0
#
#                                         thumbnail_link  comments_disabled  \
# 204547  https://i.ytimg.com/vi/bef8QLNHubw/default.jpg              False
# 17398   https://i.ytimg.com/vi/BInk1AoBHrY/default.jpg              False
# 40177   https://i.ytimg.com/vi/60g72d4Nqss/default.jpg              False
# 3347    https://i.ytimg.com/vi/G1mPnQM5hQ0/default.jpg              False
# 77387   https://i.ytimg.com/vi/x_me3xsvDgk/default.jpg              False
# ...                                                ...                ...
# 126865  https://i.ytimg.com/vi/ZoPJVcHYlU0/default.jpg               True
# 65504   https://i.ytimg.com/vi/ifJYb2An7wE/default.jpg              False
# 65528   https://i.ytimg.com/vi/kmk5vciFbek/default.jpg              False
# 74492   https://i.ytimg.com/vi/Hb3rmh-_FMw/default.jpg               True
# 80754   https://i.ytimg.com/vi/BxOEj8ZeX2g/default.jpg               True
#
#         ratings_disabled                                        description  \
# 204547             False  Bad Bunny - WHERE SHE GOES (Video Oficial)http...
# 17398              False  President-elect Joe Biden and Vice President-e...
# 40177              False  Musical guests BTS perform a stripped down cov...
# 3347               False  HI SISTERS! In today's video, I give internet ...
# 77387              False  When you love something, you protect it.Watch ...
# ...                  ...                                                ...
# 126865              True  Today’s video Doodle takes you on the ultimate...
# 65504               True  On June 25, join Daniel Howell as he celebrate...
# 65528               True  On June 25, celebrate Pride 2021 with Demi Lov...
# 74492              False  *****EPILEPSY WARNING ********Watch and create...
# 80754               True  Today's video Doodle celebrates the 32nd birth...
#
#            time_to_trend  hour_of_publishing  description_length  \
# 204547   7 days 23:59:52                   0               534.0
# 17398  -1 days +20:50:57                   3              1573.0
# 40177    7 days 19:10:31                   4               681.0
# 3347     6 days 04:59:54                  19              1229.0
# 77387    7 days 16:59:55                   7               807.0
# ...                  ...                 ...                 ...
# 126865   4 days 07:13:56                  16               769.0
# 65504    3 days 02:55:22                  21              2003.0
# 65528    2 days 23:52:41                   0              1904.0
# 74492    2 days 08:55:35                  15                79.0
# 80754    5 days 11:59:52                  12               562.0
#
#        description_category
# 204547                Short
# 17398                Medium
# 40177                 Short
# 3347                  Short
# 77387                 Short
# ...                     ...
# 126865                Short
# 65504                Medium
# 65528                Medium
# 74492                 Short
# 80754                 Short
#
# [46692 rows x 20 columns]

# %%
from matplotlib.ticker import FuncFormatter

# Function to format tick labels as integers
def format_ticks(x, pos):
    return '{:,.0f}'.format(x)

# Filter the DataFrame to include only rows where description category is 'Medium'
medium_bin_filtered_df = filtered_df[filtered_df['description_category'] == 'Medium']

# Create a histogram of view count for the medium bin
plt.figure(figsize=(10, 6))
sns.histplot(medium_bin_filtered_df['view_count'], color='skyblue')
plt.title('Histogram of View Count Videos with 1500-3399 Character Description')
plt.xlabel('View Count')
plt.ylabel('Number of Videos')
plt.show()
# Out:
# /opt/miniconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Scatter plot for views vs. description length
plt.figure(figsize=(10, 6))
plt.scatter(df['description_length'], df['view_count'], alpha=0.5)
plt.title('Scatter Plot: Views vs. Description Length')
plt.xlabel('Description Length (Characters)')
plt.ylabel('Views')
plt.grid(True)
plt.show()

# Scatter plot for likes vs. description length
plt.figure(figsize=(10, 6))
plt.scatter(df['description_length'], df['likes'], alpha=0.5)
plt.title('Scatter Plot: Likes vs. Description Length')
plt.xlabel('Description Length (Characters)')
plt.ylabel('Likes')
plt.grid(True)
plt.show()

# Scatter plot for comments vs. description length
plt.figure(figsize=(10, 6))
plt.scatter(df['description_length'], df['comment_count'], alpha=0.5)
plt.title('Scatter Plot: Comments vs. Description Length')
plt.xlabel('Description Length (Characters)')
plt.ylabel('Comments')
plt.grid(True)
plt.show()

# %%
# Box plot for views by description length category
plt.figure(figsize=(10, 6))
sns.boxplot(x='description_category', y='view_count', data=df)
plt.title('Box Plot: Views by Description Length Category')
plt.xlabel('Description Length Category')
plt.ylabel('Views')
plt.show()

# Box plot for likes by description length category
plt.figure(figsize=(10, 6))
sns.boxplot(x='description_category', y='likes', data=df)
plt.title('Box Plot: Likes by Description Length Category')
plt.xlabel('Description Length Category')
plt.ylabel('Likes')
plt.show()

# Box plot for comments by description length category
plt.figure(figsize=(10, 6))
sns.boxplot(x='description_category', y='comment_count', data=df)
plt.title('Box Plot: Comments by Description Length Category')
plt.xlabel('Description Length Category')
plt.ylabel('Comments')
plt.show()
# Out:
# /opt/miniconda3/envs/myenv/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/miniconda3/envs/myenv/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/miniconda3/envs/myenv/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Group videos by category and calculate average number of comments
comments_by_category = df.groupby('categoryId')['comment_count'].mean().reset_index()
comments_by_category
# Out:
#     categoryId  comment_count
# 0            1    7296.931223
# 1            2    3556.570010
# 2           10   25106.757179
# 3           15    3442.384236
# 4           17    3201.746396
# 5           19    2825.710963
# 6           20    5885.792667
# 7           22    6239.132817
# 8           23    5899.862069
# 9           24    8529.602377
# 10          25    4832.470960
# 11          26    4679.376206
# 12          27    5714.300946
# 13          28    5623.628571
# 14          29    5810.526316

# %%
import numpy as np

# Calculate the first quartile (Q1) and third quartile (Q3)
Q1 = df['view_count'].quantile(0.25)
Q3 = df['view_count'].quantile(0.75)

# Interquartile range (IQR)
IQR = Q3 - Q1

# Define the lower and upper bounds to identify outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['view_count'] < lower_bound) | (df['view_count'] > upper_bound)]

# Remove outliers from the DataFrame
df_filtered = df[(df['view_count'] >= lower_bound) & (df['view_count'] <= upper_bound)]

# Print the outliers
print("Outliers:")
print(outliers)

# Print the filtered DataFrame without outliers
print("\nDataFrame without outliers:")
print(df_filtered)
# Out:
# Outliers:
#            video_id                                              title  \
# 266187  cc2-4ci4G84                       Discord Loot Boxes are here.
# 152788  gQlMMD8auMs                       BLACKPINK - ‘Pink Venom’ M/V
# 56374   WMweEpGlu_U                   BTS (방탄소년단) 'Butter' Official MV
# 3358    gdZLi9oWNZg                 BTS (방탄소년단) 'Dynamite' Official MV
# 73564   hdmx71UjBXs                Turn into orbeez - Tutorial #Shorts
# ...             ...                                                ...
# 35390   6Zbhvaac68Y                                 Spot's Got an Arm!
# 69190   KISlIJDOMJU                   HIDE & SEEK ON KSI’s PRIVATE JET
# 157977  4E2EbGoXlPQ  David Blaine Does Magic While Eating Spicy Win...
# 66768   VEnNwaM_acw                    *NEW* DODGEBALL Mod in Among Us
# 252784  Vb0dG-2huJE                  A Guided Tour of Apple Vision Pro
#
#                      publishedAt                 channelId     channelTitle  \
# 266187 2024-04-01 17:46:17+00:00  UCZ5XnGb-3t7jCkXdawN2tkA          Discord
# 152788 2022-08-19 04:00:13+00:00  UCOmHUn--16B90oW2L6FRR3A        BLACKPINK
# 56374  2021-05-21 03:46:13+00:00  UC3IZKseVpdzPSBaWxBxundA      HYBE LABELS
# 3358   2020-08-21 03:58:10+00:00  UC3IZKseVpdzPSBaWxBxundA   Big Hit Labels
# 73564  2021-07-03 04:04:57+00:00  UCt8z2S30Wl-GQEluFVM8NUw           FFUNTV
# ...                          ...                       ...              ...
# 35390  2021-02-01 16:00:03+00:00  UC7vVhkEfw4nOGp8TyDk7RcQ  Boston Dynamics
# 69190  2021-07-10 18:00:06+00:00  UCh5mLn90vUaB1PbRRx_AiaA      MoreSidemen
# 157977 2022-09-29 15:00:02+00:00  UCPD_bxCRGpmmeQcbe2kpPaA   First We Feast
# 66768  2021-06-29 16:00:30+00:00  UCke6I9N4KfC968-yRcd5YRg          SSundee
# 252784 2024-01-19 15:35:11+00:00  UCE_M8A5yxnLfW0KghEeajjw            Apple
#
#         categoryId             trending_date  \
# 266187          24 2024-04-03 00:00:00+00:00
# 152788          10 2022-09-10 00:00:00+00:00
# 56374           10 2021-05-30 00:00:00+00:00
# 3358            10 2020-08-28 00:00:00+00:00
# 73564           24 2021-08-08 00:00:00+00:00
# ...            ...                       ...
# 35390           28 2021-02-08 00:00:00+00:00
# 69190           22 2021-07-17 00:00:00+00:00
# 157977          24 2022-10-06 00:00:00+00:00
# 66768           20 2021-07-05 00:00:00+00:00
# 252784          28 2024-01-26 00:00:00+00:00
#
#                                                      tags  view_count  \
# 266187                                           [[None]]  1407643634
# 152788  [YG Entertainment, YG, 와이지, K-pop, BLACKPINK, ...   277791741
# 56374              [BIGHIT, 빅히트, 방탄소년단, BTS, BANGTAN, 방탄]   264407389
# 3358               [BIGHIT, 빅히트, 방탄소년단, BTS, BANGTAN, 방탄]   232649205
# 73564                                            [[None]]   206202284
# ...                                                   ...         ...
# 35390   [Robot Manipulation, Mobile Manipulation, Legg...     4929251
# 69190   [sidemen, moresidemen, miniminter, ksi, zerkaa...     4929197
# 157977  [First we feast, fwf, firstwefeast, food, food...     4928923
# 66768                                            [[None]]     4928448
# 252784  [Apple, Apple Vision Pro, spatial computing, s...     4928205
#
#            likes  dislikes  comment_count  \
# 266187    126926         0          13987
# 152788  12993894         0        3534337
# 56374   16021534    150989        6738537
# 3358    15735533    714194        6065230
# 73564    6840430    240769           2826
# ...          ...       ...            ...
# 35390     157154      2966          14049
# 69190     356030      3250           5540
# 157977    217235         0          19814
# 66768     291677      2936          10866
# 252784    107040         0              0
#
#                                         thumbnail_link  comments_disabled  \
# 266187  https://i.ytimg.com/vi/cc2-4ci4G84/default.jpg              False
# 152788  https://i.ytimg.com/vi/gQlMMD8auMs/default.jpg              False
# 56374   https://i.ytimg.com/vi/WMweEpGlu_U/default.jpg              False
# 3358    https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg              False
# 73564   https://i.ytimg.com/vi/hdmx71UjBXs/default.jpg              False
# ...                                                ...                ...
# 35390   https://i.ytimg.com/vi/6Zbhvaac68Y/default.jpg              False
# 69190   https://i.ytimg.com/vi/KISlIJDOMJU/default.jpg              False
# 157977  https://i.ytimg.com/vi/4E2EbGoXlPQ/default.jpg              False
# 66768   https://i.ytimg.com/vi/VEnNwaM_acw/default.jpg              False
# 252784  https://i.ytimg.com/vi/Vb0dG-2huJE/default.jpg               True
#
#         ratings_disabled                                        description  \
# 266187             False  Why would we ever bring Loot Boxes into a chat...
# 152788             False  BLACKPINK - ‘Pink Venom’ M/VKick in the door W...
# 56374              False  BTS (방탄소년단) 'Butter' Official MV Credits: Dire...
# 3358               False  BTS (방탄소년단) 'Dynamite' Official MVCredits:Dire...
# 73564              False  Turn into orbeez - Tutorial #ShortsHey guys! W...
# ...                  ...                                                ...
# 35390              False  Now that Spot has an arm in addition to legs a...
# 69190              False  • Sidemen: http://www.youtube.com/Sidemen• Sid...
# 157977             False  David Blaine is known the world over for his s...
# 66768              False  Today we add a DODGEBALL Coach Imposter in Amo...
# 252784             False  Apple Vision Pro is here. Experience what it’s...
#
#           time_to_trend  hour_of_publishing  description_length  \
# 266187  1 days 06:13:43                  17               100.0
# 152788 21 days 19:59:47                   4              2279.0
# 56374   8 days 20:13:47                   3              2264.0
# 3358    6 days 20:01:50                   3              1929.0
# 73564  35 days 19:55:03                   4               248.0
# ...                 ...                 ...                 ...
# 35390   6 days 07:59:57                  16               660.0
# 69190   6 days 05:59:54                  18               487.0
# 157977  6 days 08:59:58                  15              1669.0
# 66768   5 days 07:59:30                  16               987.0
# 252784  6 days 08:24:49                  15              1218.0
#
#        description_category
# 266187                  NaN
# 152788               Medium
# 56374                Medium
# 3358                 Medium
# 73564                   NaN
# ...                     ...
# 35390                   NaN
# 69190                   NaN
# 157977               Medium
# 66768                 Short
# 252784                Short
#
# [4934 rows x 20 columns]
#
# DataFrame without outliers:
#            video_id                                              title  \
# 109776  uNShjBlrNSY           People Who Didn't Get What They Expected
# 152385  GnvVur8mv10           Telling my Son i'm PREGNANT! *Emotional*
# 237958  yY5wZemtXHI  BTS' Jung Kook Talks New Single Going Platinum...
# 5385    yTXvHXsmoqs  WANTED: Pirate Queen (Clash of Clans Season Ch...
# 100563  UZO0hqF_IkA  Legend of K-POP - TOMORROW X TOGETHER, ENHYPEN...
# ...             ...                                                ...
# 126865  ZoPJVcHYlU0                               Celebrating Route 66
# 65504   ifJYb2An7wE  Gay And Not Proud - Daniel Howell | YouTube Pr...
# 65528   kmk5vciFbek  Demi Lovato performs their greatest hits this ...
# 74492   Hb3rmh-_FMw            Introducing the shorter side of YouTube
# 80754   BxOEj8ZeX2g                       Tim Bergling's 32nd Birthday
#
#                      publishedAt                 channelId  \
# 109776 2022-02-02 22:28:57+00:00  UCpB959t8iPrxQWj7G6n0ctQ
# 152385 2022-09-01 17:31:42+00:00  UCja7QUMRG9AD8X2F_vXFb9A
# 237958 2023-11-07 05:02:09+00:00  UC8-Th83bH_thdKZDJCrn88g
# 5385   2020-09-01 07:45:00+00:00  UCD1Em4q90ZUK2R5HKesszJg
# 100563 2021-12-17 12:15:18+00:00  UC5BMQOsAB8hKUyHu9KI6yig
# ...                          ...                       ...
# 126865 2022-04-29 16:46:04+00:00  UCdq61m8s_48EhJ5OM_MCeGw
# 65504  2021-06-25 21:04:38+00:00  UCGjylN-4QCpn8XJ1uY-UOgA
# 65528  2021-06-26 00:07:19+00:00  UCZkURf9tDolFOeuw_4RD7XQ
# 74492  2021-08-10 15:04:25+00:00  UCBR8-60-B28hp2BmDPdntcQ
# 80754  2021-09-07 12:00:08+00:00  UCdq61m8s_48EhJ5OM_MCeGw
#
#                                   channelTitle  categoryId  \
# 109776                            SSSniperWolf          24
# 152385                      The Royalty Family          22
# 237958  The Tonight Show Starring Jimmy Fallon          23
# 5385                            Clash of Clans          20
# 100563                            KBS WORLD TV          10
# ...                                        ...         ...
# 126865                           GoogleDoodles           1
# 65504                            Daniel Howell          24
# 65528                              Demi Lovato          24
# 74492                                  YouTube          27
# 80754                            GoogleDoodles           1
#
#                    trending_date  \
# 109776 2022-02-07 00:00:00+00:00
# 152385 2022-09-08 00:00:00+00:00
# 237958 2023-11-13 00:00:00+00:00
# 5385   2020-09-07 00:00:00+00:00
# 100563 2021-12-23 00:00:00+00:00
# ...                          ...
# 126865 2022-05-04 00:00:00+00:00
# 65504  2021-06-29 00:00:00+00:00
# 65528  2021-06-29 00:00:00+00:00
# 74492  2021-08-13 00:00:00+00:00
# 80754  2021-09-13 00:00:00+00:00
#
#                                                      tags  view_count   likes  \
# 109776  [sssniperwolf, sniper wolf, reacting, reaction...     4926598  144890
# 152385  [The Royalty Family, Royalty Family, Andrea Es...     4926495  144664
# 237958  [tonight show, jimmy fallon, NBC, NBC TV, Tele...     4926035  416223
# 5385    [clash of clans, COC, Clash of Clans Gameplay,...     4923980   96138
# 100563  [kbs, kbsworld, kbs world, yt:cc=on, KBSWorld,...     4923686  588879
# ...                                                   ...         ...     ...
# 126865                                           [[None]]           0       0
# 65504   [Pride, Pride 2021, YouTube Pride, YouTube Pri...           0       0
# 65528   [Pride, Pride 2021, YouTube Pride, YouTube Pri...           0       0
# 74492                                            [[None]]           0   22030
# 80754                                            [[None]]           0       0
#
#         dislikes  comment_count  \
# 109776         0           5637
# 152385         0              0
# 237958         0          11060
# 5385        3567           3013
# 100563         0          26826
# ...          ...            ...
# 126865         0              0
# 65504          0           1739
# 65528          0            147
# 74492       1604              0
# 80754          0              0
#
#                                         thumbnail_link  comments_disabled  \
# 109776  https://i.ytimg.com/vi/uNShjBlrNSY/default.jpg              False
# 152385  https://i.ytimg.com/vi/GnvVur8mv10/default.jpg               True
# 237958  https://i.ytimg.com/vi/yY5wZemtXHI/default.jpg              False
# 5385    https://i.ytimg.com/vi/yTXvHXsmoqs/default.jpg              False
# 100563  https://i.ytimg.com/vi/UZO0hqF_IkA/default.jpg              False
# ...                                                ...                ...
# 126865  https://i.ytimg.com/vi/ZoPJVcHYlU0/default.jpg               True
# 65504   https://i.ytimg.com/vi/ifJYb2An7wE/default.jpg              False
# 65528   https://i.ytimg.com/vi/kmk5vciFbek/default.jpg              False
# 74492   https://i.ytimg.com/vi/Hb3rmh-_FMw/default.jpg               True
# 80754   https://i.ytimg.com/vi/BxOEj8ZeX2g/default.jpg               True
#
#         ratings_disabled                                        description  \
# 109776             False  Download Happy Clinic: https://nrdc.link/Happy...
# 152385             False  Telling my Son i'm PREGNANT! *Emotional*𝐒𝐔𝐁𝐒𝐂𝐑...
# 237958             False  Jung Kook talks about his accomplishments with...
# 5385               False  Follow us on our Socials!Twitter ► https://twi...
# 100563             False  #TOMORROWXTOGETHER #ENHYPEN[KBS Song Festival]...
# ...                  ...                                                ...
# 126865              True  Today’s video Doodle takes you on the ultimate...
# 65504               True  On June 25, join Daniel Howell as he celebrate...
# 65528               True  On June 25, celebrate Pride 2021 with Demi Lov...
# 74492              False  *****EPILEPSY WARNING ********Watch and create...
# 80754               True  Today's video Doodle celebrates the 32nd birth...
#
#          time_to_trend  hour_of_publishing  description_length  \
# 109776 4 days 01:31:03                  22               545.0
# 152385 6 days 06:28:18                  17              1244.0
# 237958 5 days 18:57:51                   5              1703.0
# 5385   5 days 16:15:00                   7              1737.0
# 100563 5 days 11:44:42                  12              1290.0
# ...                ...                 ...                 ...
# 126865 4 days 07:13:56                  16               769.0
# 65504  3 days 02:55:22                  21              2003.0
# 65528  2 days 23:52:41                   0              1904.0
# 74492  2 days 08:55:35                  15                79.0
# 80754  5 days 11:59:52                  12               562.0
#
#        description_category
# 109776                  NaN
# 152385                Short
# 237958               Medium
# 5385                 Medium
# 100563                Short
# ...                     ...
# 126865                  NaN
# 65504                Medium
# 65528                Medium
# 74492                   NaN
# 80754                   NaN
#
# [42520 rows x 20 columns]

# %%
# Calculate Pearson correlation coefficient between description length and views
correlation = df['description_length'].corr(df['view_count'])

print("Pearson correlation coefficient between description length and views:", correlation)
# Out:
# Pearson correlation coefficient between description length and views: 0.033531003548923924

# %%
# Create a joint plot with hexbin representation
plt.figure(figsize=(10, 6))
sns.jointplot(x='description_length', y='view_count', data=df, kind='hex', gridsize=20)
plt.title('Joint Plot with Hexbin Representation: Description Length vs. Views')
plt.xlabel('Description Length (Characters)')
plt.ylabel('Views')
plt.xlim(0, df['description_length'].max())  # Adjust x-axis limit to the maximum description length
plt.ylim(0, df['view_count'].max())  # Adjust y-axis limit to the maximum view count
plt.show()
# Out:
# /opt/miniconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/miniconda3/envs/myenv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the bins for description length
bins = pd.cut(df['description_length'], bins=100)  # Adjust the number of bins as needed

# Calculate the average views within each bin
views_by_description_length = df.groupby(bins)['view_count'].mean()

# Plot the bar graph
plt.figure(figsize=(10, 6))
views_by_description_length.plot(kind='bar', color='skyblue')
plt.title('Average Views by Description Length')
plt.xlabel('Description Length (Bins)')
plt.ylabel('Average Views')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# /var/folders/03/4fzp3dpd36s1z9wlxm8hzlv00000gn/T/ipykernel_76500/2039698024.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   views_by_description_length = df.groupby(bins)['view_count'].mean()

# %%
# Create a scatter plot with regression line
plt.figure(figsize=(10, 6))
sns.regplot(x='description_length', y='view_count', data=df, scatter_kws={'alpha':0.5})
plt.title('Scatter Plot with Regression Line: Description Length vs. Views')
plt.xlabel('Description Length (Characters)')
plt.ylabel('Views')
plt.grid(True)
plt.show()

# %%
# Group videos by category and calculate total comments
comments_by_category = df.groupby('categoryId')['comment_count'].sum().reset_index()

# Sort the data by total comments
comments_by_category = comments_by_category.sort_values(by='comment_count', ascending=False)

# Visualize the results
plt.figure(figsize=(12, 6))
sns.barplot(x='categoryId', y='comment_count', data=comments_by_category)
plt.title('Total Comments by Video Category')
plt.xlabel('Category ID')
plt.ylabel('Total Comments')
plt.xticks(rotation=45)
plt.show()

# %%
# Group videos by category and calculate average number of comments
comments_by_category = df.groupby('categoryId')['comment_count'].mean().reset_index()

# Sort the data by average number of comments
comments_by_category = comments_by_category.sort_values(by='comment_count', ascending=False)

# Visualize the results
plt.figure(figsize=(12, 6))
sns.barplot(x='categoryId', y='comment_count', data=comments_by_category)
plt.title('Average Number of Comments by Video Category')
plt.xlabel('Category ID')
plt.ylabel('Average Number of Comments')
plt.xticks(rotation=45)
plt.show()

# %%
# Group videos by category and calculate total views
views_by_category = df.groupby('categoryId')['view_count'].sum().reset_index()

# Sort the data by total views
views_by_category = views_by_category.sort_values(by='view_count', ascending=False)

# Visualize the results
plt.figure(figsize=(12, 6))
sns.barplot(x='categoryId', y='view_count', data=views_by_category)
plt.title('Total Views by Video Category')
plt.xlabel('Category ID')
plt.ylabel('Total Views')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.pie(views_by_category['view_count'], labels=views_by_category['categoryId'], autopct='%1.1f%%')
plt.title('Total Views by Video Category (Pie Chart)')
plt.show()

# %%
# Group videos by channel and calculate total comments
comments_by_channel = df.groupby('channelTitle')['comment_count'].sum().reset_index()

# Sort the data by total comments
comments_by_channel = comments_by_channel.sort_values(by='comment_count', ascending=False)

# Visualize the results
plt.figure(figsize=(12, 6))
sns.barplot(x='comment_count', y='channelTitle', data=comments_by_channel.head(10))  # Plot only top 10 channels
plt.title('Total Comments by Channel')
plt.xlabel('Total Comments')
plt.ylabel('Channel Title')
plt.show()
# Out:
# /opt/miniconda3/envs/myenv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda3/envs/myenv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda3/envs/myenv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Group videos by channel and calculate average number of comments
comments_by_channel = df.groupby('channelTitle')['comment_count'].mean().reset_index()

# Sort the data by average number of comments
comments_by_channel = comments_by_channel.sort_values(by='comment_count', ascending=False)

# Visualize the results
plt.figure(figsize=(12, 6))
sns.barplot(x='channelTitle', y='comment_count', data=comments_by_channel.head(10))  # Plot only top 10 channels
plt.title('Average Number of Comments by Channel')
plt.xlabel('Channel Title')
plt.ylabel('Average Number of Comments')
plt.xticks(rotation=45)
plt.show()
# Out:
# /opt/miniconda3/envs/myenv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda3/envs/myenv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda3/envs/myenv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Group videos by channel and calculate total views
views_by_channel = df.groupby('channelTitle')['view_count'].sum().reset_index()

# Sort the data by total views
views_by_channel = views_by_channel.sort_values(by='view_count', ascending=False)

# Visualize the results
plt.figure(figsize=(12, 6))
sns.barplot(x='view_count', y='channelTitle', data=views_by_channel.head(10))  # Plot only top 10 channels
plt.title('Total Views by Channel')
plt.xlabel('Total Views')
plt.ylabel('Channel Title')
plt.show()
